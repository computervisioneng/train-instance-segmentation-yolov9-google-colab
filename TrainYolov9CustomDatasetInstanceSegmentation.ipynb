# %%
### 0. Mount Google Drive ###

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 1. Prepare data ###

# !scp '/content/gdrive/My Drive/Yolov9InstanceSegmentationGoogleColab/data.zip' '/content/data.zip'

# !unzip '/content/data.zip' -d '/content/'

# %%
### 2. Clone repository ###

# !git clone https://github.com/computervisioneng/yolov9

# %cd yolov9

# %%
### 3. Install requirements ###

# !pip install -r requirements.txt

# %%
### 4. Train model ###

from yolov9 import Yolov9

model = Yolov9('instance-segmentation')

model.train(data='/content/gdrive/My Drive/Yolov9InstanceSegmentationGoogleColab/data.yaml', epochs=1)

# %%
### 4. Copy results ###

# !zip -r /content/runs.zip /content/yolov9/runs

# !scp '/content/runs.zip' '/content/gdrive/My Drive/Yolov9InstanceSegmentationGoogleColab/runs.zip'
